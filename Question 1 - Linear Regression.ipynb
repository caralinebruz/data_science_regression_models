# %% [markdown]
# # Q1: Linear Regression
#
# Introduction to Data Science (DS-GA1001)

# %% [markdown]
# #### Import libraries

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %% [markdown]
# #### Ingest data

# %%
df = pd.read_csv('movieReplicationSet.csv')

# %%
df
# Out:
#       The Life of David Gale (2003)  Wing Commander (1999)  \
# 0                               NaN                    NaN
# 1                               NaN                    NaN
# 2                               NaN                    NaN
# 3                               NaN                    NaN
# 4                               NaN                    NaN
# ...                             ...                    ...
# 1092                            NaN                    NaN
# 1093                            3.0                    4.0
# 1094                            NaN                    NaN
# 1095                            NaN                    NaN
# 1096                            NaN                    NaN
#
#       Django Unchained (2012)  Alien (1979)  \
# 0                         4.0           NaN
# 1                         1.5           NaN
# 2                         NaN           NaN
# 3                         2.0           NaN
# 4                         3.5           NaN
# ...                       ...           ...
# 1092                      NaN           NaN
# 1093                      NaN           NaN
# 1094                      NaN           NaN
# 1095                      NaN           NaN
# 1096                      4.0           NaN
#
#       Indiana Jones and the Last Crusade (1989)  Snatch (2000)  \
# 0                                           3.0            NaN
# 1                                           NaN            NaN
# 2                                           NaN            NaN
# 3                                           3.0            NaN
# 4                                           0.5            NaN
# ...                                         ...            ...
# 1092                                        3.5            NaN
# 1093                                        4.0            4.0
# 1094                                        NaN            NaN
# 1095                                        NaN            NaN
# 1096                                        2.5            NaN
#
#       Rambo: First Blood Part II (1985)  Fargo (1996)  \
# 0                                   NaN           NaN
# 1                                   NaN           NaN
# 2                                   NaN           NaN
# 3                                   NaN           NaN
# 4                                   0.5           1.0
# ...                                 ...           ...
# 1092                                NaN           NaN
# 1093                                2.5           NaN
# 1094                                NaN           3.5
# 1095                                NaN           NaN
# 1096                                NaN           3.0
#
#       Let the Right One In (2008)  Black Swan (2010)  ...  \
# 0                             NaN                NaN  ...
# 1                             NaN                NaN  ...
# 2                             NaN                NaN  ...
# 3                             NaN                4.0  ...
# 4                             NaN                0.0  ...
# ...                           ...                ...  ...
# 1092                          NaN                NaN  ...
# 1093                          3.5                3.5  ...
# 1094                          NaN                NaN  ...
# 1095                          NaN                NaN  ...
# 1096                          NaN                3.5  ...
#
#       When watching a movie I cheer or shout or talk or curse at the screen  \
# 0                                                   1.0
# 1                                                   3.0
# 2                                                   5.0
# 3                                                   3.0
# 4                                                   2.0
# ...                                                 ...
# 1092                                                3.0
# 1093                                                5.0
# 1094                                                6.0
# 1095                                                1.0
# 1096                                                3.0
#
#       When watching a movie I feel like the things on the screen are happening to me  \
# 0                                                   6.0
# 1                                                   1.0
# 2                                                   4.0
# 3                                                   1.0
# 4                                                   3.0
# ...                                                 ...
# 1092                                                4.0
# 1093                                                3.0
# 1094                                                3.0
# 1095                                                1.0
# 1096                                                4.0
#
#       As a movie unfolds I start to have problems keeping track of events that happened earlier  \
# 0                                                   2.0
# 1                                                   1.0
# 2                                                   3.0
# 3                                                   1.0
# 4                                                   2.0
# ...                                                 ...
# 1092                                                3.0
# 1093                                                5.0
# 1094                                                1.0
# 1095                                                1.0
# 1096                                                1.0
#
#       The emotions on the screen "rub off" on me - for instance if something sad is happening I get sad or if something frightening is happening I get scared  \
# 0                                                   5.0
# 1                                                   6.0
# 2                                                   5.0
# 3                                                   4.0
# 4                                                   5.0
# ...                                                 ...
# 1092                                                5.0
# 1093                                                5.0
# 1094                                                6.0
# 1095                                                4.0
# 1096                                                4.0
#
#       When watching a movie I get completely immersed in the alternative reality of the film  \
# 0                                                   5.0
# 1                                                   5.0
# 2                                                   5.0
# 3                                                   5.0
# 4                                                   6.0
# ...                                                 ...
# 1092                                                5.0
# 1093                                                5.0
# 1094                                                6.0
# 1095                                                3.0
# 1096                                                4.0
#
#       Movies change my position on social economic or political issues  \
# 0                                                   5.0
# 1                                                   3.0
# 2                                                   4.0
# 3                                                   3.0
# 4                                                   4.0
# ...                                                 ...
# 1092                                                4.0
# 1093                                                6.0
# 1094                                                4.0
# 1095                                                3.0
# 1096                                                4.0
#
#       When watching movies things get so intense that I have to stop watching  \
# 0                                                   1.0
# 1                                                   2.0
# 2                                                   4.0
# 3                                                   1.0
# 4                                                   4.0
# ...                                                 ...
# 1092                                                4.0
# 1093                                                5.0
# 1094                                                2.0
# 1095                                                1.0
# 1096                                                1.0
#
#       Gender identity (1 = female; 2 = male; 3 = self-described)  \
# 0                                                   1.0
# 1                                                   1.0
# 2                                                   1.0
# 3                                                   1.0
# 4                                                   1.0
# ...                                                 ...
# 1092                                                1.0
# 1093                                                1.0
# 1094                                                1.0
# 1095                                                1.0
# 1096                                                1.0
#
#       Are you an only child? (1: Yes; 0: No; -1: Did not respond)  \
# 0                                                     0
# 1                                                     0
# 2                                                     1
# 3                                                     0
# 4                                                     1
# ...                                                 ...
# 1092                                                  0
# 1093                                                  0
# 1094                                                  0
# 1095                                                  0
# 1096                                                  0
#
#       Movies are best enjoyed alone (1: Yes; 0: No; -1: Did not respond)
# 0                                                     1
# 1                                                     0
# 2                                                     0
# 3                                                     1
# 4                                                     1
# ...                                                 ...
# 1092                                                  0
# 1093                                                  0
# 1094                                                  0
# 1095                                                  1
# 1096                                                  1
#
# [1097 rows x 477 columns]

# %%
print(len(df.columns))     # 477 without 'mean', 478 with 'mean'
# Out:
# 477

# %%
cols = df.columns
b_cols = cols[400:]
rating_cols = cols[:400]

# %%
# get a dataframe of the movies only
df = df[rating_cols]

# %%
# creates a dictionary of the mean value of each column

# returns a dictionary of column and its mean value
def make_column_means(M):
    column_means = {}
    
    for col in M.columns:
#         print(col)
        colmean = M[col].mean()
        column_means[str(col)] = colmean

    return column_means

# %%
def append_rowmeans(M):

    M['mean'] = M.mean(axis=1)
#     return M

# %%
# replace nans 
# first gets all of the column means
# then makes a new column for the rowmean
# for a given nan, replace it with the average of its rowmean and its colmean
def enrich_nans(M):
    
    column_means = make_column_means(M)
#     M = append_rowmeans(M)
    append_rowmeans(M)
    
    # for every column
    for col in M.columns:

        for row in range(len(M)):
            value = M.at[row, col]

            if np.isnan(value):
                rowmean = M.at[row, 'mean']
                colmean = column_means[col]
                newvalue = (rowmean + colmean) / 2

#                 print("rowmean: %s, colmean: %s ==> NEW: %s" % (rowmean, colmean, newvalue))
                M.at[row, col] = newvalue
                
    return M

# %%
# double check you captured all nans and converted them. should be 0 nans left at this point
df.isna().sum().sum()
# Out:
# 326586

# %%
# get a dataframe of the movies only
df = df[rating_cols]
df
# Out:
#       The Life of David Gale (2003)  Wing Commander (1999)  \
# 0                               NaN                    NaN
# 1                               NaN                    NaN
# 2                               NaN                    NaN
# 3                               NaN                    NaN
# 4                               NaN                    NaN
# ...                             ...                    ...
# 1092                            NaN                    NaN
# 1093                            3.0                    4.0
# 1094                            NaN                    NaN
# 1095                            NaN                    NaN
# 1096                            NaN                    NaN
#
#       Django Unchained (2012)  Alien (1979)  \
# 0                         4.0           NaN
# 1                         1.5           NaN
# 2                         NaN           NaN
# 3                         2.0           NaN
# 4                         3.5           NaN
# ...                       ...           ...
# 1092                      NaN           NaN
# 1093                      NaN           NaN
# 1094                      NaN           NaN
# 1095                      NaN           NaN
# 1096                      4.0           NaN
#
#       Indiana Jones and the Last Crusade (1989)  Snatch (2000)  \
# 0                                           3.0            NaN
# 1                                           NaN            NaN
# 2                                           NaN            NaN
# 3                                           3.0            NaN
# 4                                           0.5            NaN
# ...                                         ...            ...
# 1092                                        3.5            NaN
# 1093                                        4.0            4.0
# 1094                                        NaN            NaN
# 1095                                        NaN            NaN
# 1096                                        2.5            NaN
#
#       Rambo: First Blood Part II (1985)  Fargo (1996)  \
# 0                                   NaN           NaN
# 1                                   NaN           NaN
# 2                                   NaN           NaN
# 3                                   NaN           NaN
# 4                                   0.5           1.0
# ...                                 ...           ...
# 1092                                NaN           NaN
# 1093                                2.5           NaN
# 1094                                NaN           3.5
# 1095                                NaN           NaN
# 1096                                NaN           3.0
#
#       Let the Right One In (2008)  Black Swan (2010)  ...  X-Men 2 (2003)  \
# 0                             NaN                NaN  ...             NaN
# 1                             NaN                NaN  ...             NaN
# 2                             NaN                NaN  ...             NaN
# 3                             NaN                4.0  ...             NaN
# 4                             NaN                0.0  ...             2.5
# ...                           ...                ...  ...             ...
# 1092                          NaN                NaN  ...             NaN
# 1093                          3.5                3.5  ...             4.0
# 1094                          NaN                NaN  ...             NaN
# 1095                          NaN                NaN  ...             NaN
# 1096                          NaN                3.5  ...             NaN
#
#       The Usual Suspects (1995)  The Mask (1994)  Jaws (1975)  \
# 0                           NaN              NaN          4.0
# 1                           NaN              NaN          NaN
# 2                           NaN              NaN          NaN
# 3                           3.0              NaN          NaN
# 4                           NaN              3.0          NaN
# ...                         ...              ...          ...
# 1092                        NaN              NaN          NaN
# 1093                        NaN              4.0          3.5
# 1094                        NaN              NaN          NaN
# 1095                        NaN              NaN          NaN
# 1096                        NaN              NaN          3.5
#
#       Harry Potter and the Chamber of Secrets (2002)  Patton (1970)  \
# 0                                                0.5            NaN
# 1                                                4.0            NaN
# 2                                                3.5            NaN
# 3                                                2.5            NaN
# 4                                                NaN            NaN
# ...                                              ...            ...
# 1092                                             4.0            NaN
# 1093                                             3.5            4.0
# 1094                                             4.0            NaN
# 1095                                             2.5            NaN
# 1096                                             4.0            NaN
#
#       Anaconda (1997)  Twister (1996)  MacArthur (1977)  \
# 0                 NaN             NaN               NaN
# 1                 NaN             NaN               NaN
# 2                 NaN             NaN               NaN
# 3                 NaN             NaN               NaN
# 4                 NaN             1.5               NaN
# ...               ...             ...               ...
# 1092              NaN             NaN               NaN
# 1093              3.5             4.0               4.0
# 1094              NaN             NaN               NaN
# 1095              NaN             NaN               NaN
# 1096              NaN             NaN               NaN
#
#       Look Who's Talking (1989)
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# ...                         ...
# 1092                        NaN
# 1093                        4.0
# 1094                        NaN
# 1095                        NaN
# 1096                        NaN
#
# [1097 rows x 400 columns]

# %%
# add a placeholder for the new column
df['mean'] = np.nan

# %%
# do the missing value handling as described in the doc
df = enrich_nans(df)
df
# Out:
#       The Life of David Gale (2003)  Wing Commander (1999)  \
# 0                          2.447086               2.381992
# 1                          2.439294               2.374200
# 2                          2.733065               2.667971
# 3                          2.282975               2.217880
# 4                          2.209132               2.144038
# ...                             ...                    ...
# 1092                       2.675658               2.610563
# 1093                       3.000000               4.000000
# 1094                       2.641923               2.576828
# 1095                       2.770970               2.705876
# 1096                       2.512595               2.447500
#
#       Django Unchained (2012)  Alien (1979)  \
# 0                    4.000000      2.725235
# 1                    1.500000      2.717443
# 2                    3.234118      3.011214
# 3                    2.000000      2.561123
# 4                    3.500000      2.487281
# ...                       ...           ...
# 1092                 3.176711      2.953806
# 1093                 3.413546      3.190641
# 1094                 3.142976      2.920071
# 1095                 3.272023      3.049119
# 1096                 4.000000      2.790743
#
#       Indiana Jones and the Last Crusade (1989)  Snatch (2000)  \
# 0                                      3.000000       2.670257
# 1                                      2.752945       2.662464
# 2                                      3.046716       2.956236
# 3                                      3.000000       2.506145
# 4                                      0.500000       2.432303
# ...                                         ...            ...
# 1092                                   3.500000       2.898828
# 1093                                   4.000000       4.000000
# 1094                                   2.955574       2.865093
# 1095                                   3.084621       2.994141
# 1096                                   2.500000       2.735765
#
#       Rambo: First Blood Part II (1985)  Fargo (1996)  \
# 0                              2.554121      2.821232
# 1                              2.546329      2.813440
# 2                              2.840100      3.107211
# 3                              2.390009      2.657120
# 4                              0.500000      1.000000
# ...                                 ...           ...
# 1092                           2.782692      3.049803
# 1093                           2.500000      3.286638
# 1094                           2.748957      3.500000
# 1095                           2.878005      3.145116
# 1096                           2.619629      3.000000
#
#       Let the Right One In (2008)  Black Swan (2010)  ...  \
# 0                        2.619604           2.827211  ...
# 1                        2.611812           2.819419  ...
# 2                        2.905583           3.113190  ...
# 3                        2.455492           4.000000  ...
# 4                        2.381650           0.000000  ...
# ...                           ...                ...  ...
# 1092                     2.848175           3.055782  ...
# 1093                     3.500000           3.500000  ...
# 1094                     2.814440           3.022047  ...
# 1095                     2.943488           3.151095  ...
# 1096                     2.685112           3.500000  ...
#
#       The Usual Suspects (1995)  The Mask (1994)  Jaws (1975)  \
# 0                      2.921947         2.650951     4.000000
# 1                      2.914154         2.643159     2.673112
# 2                      3.207926         2.936930     2.966883
# 3                      3.000000         2.486840     2.516793
# 4                      2.683993         3.000000     2.442950
# ...                         ...              ...          ...
# 1092                   3.150518         2.879523     2.909476
# 1093                   3.387353         4.000000     3.500000
# 1094                   3.116783         2.845788     2.875741
# 1095                   3.245831         2.974835     3.004788
# 1096                   2.987455         2.716460     3.500000
#
#       Harry Potter and the Chamber of Secrets (2002)  Patton (1970)  \
# 0                                           0.500000       2.510773
# 1                                           4.000000       2.502981
# 2                                           3.500000       2.796752
# 3                                           2.500000       2.346661
# 4                                           2.769704       2.272819
# ...                                              ...            ...
# 1092                                        4.000000       2.739344
# 1093                                        3.500000       4.000000
# 1094                                        4.000000       2.705609
# 1095                                        2.500000       2.834657
# 1096                                        4.000000       2.576281
#
#       Anaconda (1997)  Twister (1996)  MacArthur (1977)  \
# 0            2.519156        2.572578          2.428806
# 1            2.511364        2.564786          2.421013
# 2            2.805135        2.858557          2.714784
# 3            2.355044        2.408466          2.264694
# 4            2.281202        1.500000          2.190852
# ...               ...             ...               ...
# 1092         2.747727        2.801149          2.657377
# 1093         3.500000        4.000000          4.000000
# 1094         2.713992        2.767414          2.623642
# 1095         2.843040        2.896462          2.752690
# 1096         2.584664        2.638086          2.494314
#
#       Look Who's Talking (1989)      mean
# 0                      2.540410  2.742857
# 1                      2.532618  2.727273
# 2                      2.826389  3.314815
# 3                      2.376299  2.414634
# 4                      2.302456  2.266949
# ...                         ...       ...
# 1092                   2.768981  3.200000
# 1093                   4.000000  3.673669
# 1094                   2.735247  3.132530
# 1095                   2.864294  3.390625
# 1096                   2.605918  2.873874
#
# [1097 rows x 401 columns]

# %%
df.isna().sum()
# Out:
# The Life of David Gale (2003)                1
# Wing Commander (1999)                        1
# Django Unchained (2012)                      1
# Alien (1979)                                 1
# Indiana Jones and the Last Crusade (1989)    1
#                                             ..
# Anaconda (1997)                              1
# Twister (1996)                               1
# MacArthur (1977)                             1
# Look Who's Talking (1989)                    1
# mean                                         1
# Length: 401, dtype: int64

# %%
df = df.dropna()

# %% [markdown]
# ## Done with enriching and cleaning, on to simple linear regression model

# %%
# confirm the first movie column and the last one
df.columns[0] # wing commander, we need to index at 0
df.columns[399] # Look Whos Talking, the final movie col
max_index = 399
# df.columns[400] # -> 'I enjoy driving fast'

# %%
'''
reg = LinearRegression().fit(x.reshape(-1,1), y)
                # x = test values (if we were doing cross validation)
y_hat = reg.predict(x.reshape(-1,1))

r2 = r2_score(y,y_hat)   
print('R^2:', r2.round(3))
rmse = np.sqrt(np.mean(np.sum((y-y_hat)**2)))
print('RMSE:', rmse.round(3))
'''


def linreg(x,y, name1,name2):
    reg = LinearRegression().fit(x.reshape(-1,1), y)
#     y_hat = float(reg.coef_)*x + reg.intercept_
    y_hat = reg.predict(x.reshape(-1,1))
    # y = m*x + b

#     # plot that line
#     plt.figure(figsize=(8,5))
#     plt.plot(x, y, 'o', ms=2) # scatter plot, using 'o'
#     plt.plot(x, y_hat, color='orange', linewidth=0.5) # orange line for the fox
#     plt.xlabel(name1)
#     plt.ylabel(name2)
#     plt.show()
    
    optimal_beta = float(reg.coef_.round(3))
    offset = reg.intercept_.round(3)           # offset is the y-intercept
    r2 = r2_score(y,y_hat)
    rmse = np.sqrt(np.mean(np.sum((y-y_hat)**2)))

#     print('\t Optimal beta:', optimal_beta)
#     print('\t Offset:', offset)
#     print("\t r^2 = %s , rmse = %s" % (r2, rmse))
    
    return r2, rmse

# %%
'''Please include a histogram of these 400 COD values and a table with the 10 movies that are most
easily predicted from the ratings of a single other movie and the 10 movies that are hardest to predict
from the ratings of a single other movie (and their associated COD values, as well as which movie
ratings are the best predictor, so this table should have 3 columns).
'''

def Average(lst):
    return sum(lst) / len(lst)


def rank_scores(obj):
    n = 1
    r2 = []
    for o_movie, vals in obj.items():
        r2.append(vals['r2'])

    average_r2 = Average(r2)
    
    best_ten = r2.copy()
    best_ten = sorted(best_ten, reverse=True)
    best_ten = best_ten[:n]
    
    worst_ten = r2.copy()
    worst_ten = sorted(worst_ten)
    worst_ten = worst_ten[:n]
            
#     print(best_ten)
#     print(worst_ten)
    
    # return an array of the objects
    # best
    obj_b = obj.copy()
    best = []
    for score in best_ten:
        for m, v in obj_b.copy().items():

            if v['r2'] == score:
                this_movie_item = {}
                this_movie_item[m] = v
                best.append(this_movie_item)
                
                # also remove it from objs
                del obj_b[m]
                
    obj_w = obj.copy()
    worst = []
    for score in worst_ten:
        for m, v in obj_w.copy().items():
            
            if v['r2'] == score:
                this_movie_item = {}
                this_movie_item[m] = v
                worst.append(this_movie_item)
                
                # also remove it from objs
                del obj_w[m]
        
            
    return best, worst, average_r2

# %%
# Wing Commander (1999)
# Look Who's Talking (1989)

cols = df.columns
movie_columns = cols[:400].tolist()

average_CODs = []
best_CODs = []
best_data_all = []

for movie in movie_columns:
    print("Finding best predictor: '%s'" % movie)
    
    this_movie_scores = {}
    x = pd.to_numeric(df[movie],errors='coerce').values

    other_movies = movie_columns.copy()
    other_movies.remove(movie)
    
    for other_movie in other_movies:
        #print("\tOther movie: '%s'" % other_movie)
        y = pd.to_numeric(df[other_movie],errors='coerce').values
        r2, rmse = linreg(x,y, movie,other_movie)
        this_movie_scores[other_movie] = {"x":x, "y":y, "r2":r2, "rmse":rmse}
        
    # assess scores for the 399 models made for this single movie
    best, worst, avg_cod = rank_scores(this_movie_scores)
    y_movie = dict(best[0])
    best_name = list(y_movie.keys())[0]
    best_cod = y_movie[best_name]['r2']
    best_data = {'movie': movie, 'other_movie': best_name, 'cod': best_cod}
#     best_data['movie'] = movie
    best_data_all.append(best_data)

    # i need name of movie and best cod score
    # i need a histogram of the average COD of each movie model
    average_CODs.append(avg_cod)
    best_CODs.append(best_cod)
# Out:
# Finding best predictor: 'The Life of David Gale (2003)'
# Finding best predictor: 'Wing Commander (1999)'
# Finding best predictor: 'Django Unchained (2012)'
# Finding best predictor: 'Alien (1979)'
# Finding best predictor: 'Indiana Jones and the Last Crusade (1989)'
# Finding best predictor: 'Snatch (2000)'
# Finding best predictor: 'Rambo: First Blood Part II (1985)'
# Finding best predictor: 'Fargo (1996)'
# Finding best predictor: 'Let the Right One In (2008)'
# Finding best predictor: 'Black Swan (2010)'
# Finding best predictor: 'King Kong (1976)'
# Finding best predictor: 'The Machinist (2004)'
# Finding best predictor: 'A Nightmare on Elm Street (1984)'
# Finding best predictor: 'Brazil (1985)'
# Finding best predictor: 'The Fast and the Furious (2001)'
# Finding best predictor: 'Change of Habit (1969)'
# Finding best predictor: 'American Beauty (1999)'
# Finding best predictor: 'Psycho (1960)'
# Finding best predictor: 'Terminator 3: Rise of the Machines (2003)'
# Finding best predictor: 'Night of the Living Dead (1968)'
# Finding best predictor: 'Man on Fire (2004)'
# Finding best predictor: 'Star Wars: Episode IV - A New Hope (1977)'
# Finding best predictor: 'The Silence of the Lambs (1991)'
# Finding best predictor: 'The Others (2001)'
# Finding best predictor: 'Minority Report (2002)'
# Finding best predictor: 'Sling Blade (1996)'
# Finding best predictor: 'Schindler's List (1993)'
# Finding best predictor: '3000 Miles to Graceland (2001)'
# Finding best predictor: 'Magnolia (1999)'
# Finding best predictor: 'The Karate Kid Part II (1986)'
# Finding best predictor: 'Planet of the Apes (2001)'
# Finding best predictor: 'The Godfather: Part II (1974)'
# Finding best predictor: 'Indiana Jones and the Temple of Doom (1984)'
# Finding best predictor: 'Indiana Jones and the Raiders of the Lost Ark (1981)'
# Finding best predictor: 'The Iron Giant (1999)'
# Finding best predictor: 'The Matrix Revolutions (2003)'
# Finding best predictor: 'North (1994)'
# Finding best predictor: 'The Lost World: Jurassic Park (1997)'
# Finding best predictor: 'The Texas Chainsaw Massacre (1974)'
# Finding best predictor: 'Taxi Driver (1976)'
# Finding best predictor: 'Back to the Future (1985)'
# Finding best predictor: '13 Going on 30 (2004)'
# Finding best predictor: 'Sorority Boys (2002)'
# Finding best predictor: 'The Bridges of Madison County (1995)'
# Finding best predictor: 'Billy Madison (1995)'
# Finding best predictor: 'Chain Reaction (1996)'
# Finding best predictor: 'Batman & Robin (1997)'
# Finding best predictor: 'Jurassic Park III (2001)'
# Finding best predictor: 'Platoon (1986)'
# Finding best predictor: 'Signs (2002)'
# Finding best predictor: 'Terms of Endearment (1983)'
# Finding best predictor: 'Mission: Impossible II (2000)'
# Finding best predictor: 'Lost in Translation (2003)'
# Finding best predictor: 'Star Trek: The Motion Picture (1979)'
# Finding best predictor: 'Inglorious Bastards (2009)'
# Finding best predictor: 'Clueless (1995)'
# Finding best predictor: 'The Omen (1976)'
# Finding best predictor: 'Shrek 2 (2004)'
# Finding best predictor: 'Good Will Hunting (1997)'
# Finding best predictor: 'Just Like Heaven (2005)'
# Finding best predictor: 'Showgirls (1995)'
# Finding best predictor: 'Diamonds are Forever (1971)'
# Finding best predictor: 'Crossroads (2002)'
# Finding best predictor: 'Pieces of April (2003)'
# Finding best predictor: 'Torque (2004)'
# Finding best predictor: 'Poltergeist (1982)'
# Finding best predictor: 'Fear and Loathing in Las Vegas (1998)'
# Finding best predictor: 'Barbarella (1968)'
# Finding best predictor: 'The King of Marvin Gardens (1972)'
# Finding best predictor: 'The Poseidon Adventure (1972)'
# Finding best predictor: 'The Rock (1996)'
# Finding best predictor: 'Love Story (1970)'
# Finding best predictor: 'The Last Samurai (2003)'
# Finding best predictor: 'The Jungle Book (1967)'
# Finding best predictor: 'The Exorcist (1973)'
# Finding best predictor: 'Pirates of the Caribbean: Dead Man's Chest (2006)'
# Finding best predictor: 'Gone in Sixty Seconds (2000)'
# Finding best predictor: 'Funny Girl (1968)'
# Finding best predictor: 'Honey (2003)'
# Finding best predictor: 'Blues Brothers 2000 (1998)'
# Finding best predictor: 'Avatar (2009)'
# Finding best predictor: 'The Pianist (2002)'
# Finding best predictor: 'Godzilla (1998)'
# Finding best predictor: 'Fight Club (1999)'
# Finding best predictor: 'The Conjuring (2013)'
# Finding best predictor: 'Top Gun (1986)'
# Finding best predictor: 'Slackers (2002)'
# Finding best predictor: 'Shrek (2001)'
# Finding best predictor: '12 Monkeys (1995)'
# Finding best predictor: 'From Hell (2001)'
# Finding best predictor: 'Dead Poets Society (1989)'
# Finding best predictor: 'Once Upon a Time in America (1984)'
# Finding best predictor: 'Equilibrium (2002)'
# Finding best predictor: 'Star Wars: Episode II - Attack of the Clones (2002)'
# Finding best predictor: 'The Thing (1982)'
# Finding best predictor: 'Interstellar (2014)'
# Finding best predictor: 'Full Metal Jacket (1987)'
# Finding best predictor: 'Big Fish (2003)'
# Finding best predictor: 'Cool Hand Luke (1967)'
# Finding best predictor: 'A Beautiful Mind (2001)'
# Finding best predictor: 'Sholay (1978)'
# Finding best predictor: 'The 51st State (2001)'
# Finding best predictor: 'Die Hard With a Vengeance (1995)'
# Finding best predictor: 'Elf (2003)'
# Finding best predictor: 'The Blue Lagoon (1980)'
# Finding best predictor: 'Hellraiser (1987)'
# Finding best predictor: 'Moonraker (1979)'
# Finding best predictor: 'Leon (1994)'
# Finding best predictor: 'Mystic River (2003)'
# Finding best predictor: 'Sexy Beast (2000)'
# Finding best predictor: 'Beetle Juice (1988)'
# Finding best predictor: 'Andaz Apna Apna (1994)'
# Finding best predictor: 'The Proposal (2009)'
# Finding best predictor: 'The Shining (1980)'
# Finding best predictor: 'The Land That Time Forgot (1974)'
# Finding best predictor: 'The Perfect Storm (2000)'
# Finding best predictor: 'Escape from LA (1996)'
# Finding best predictor: 'Shutter Island (2010)'
# Finding best predictor: 'JFK (1991)'
# Finding best predictor: 'Barb Wire (1996)'
# Finding best predictor: 'Oldboy (2003)'
# Finding best predictor: 'Carrie (1976)'
# Finding best predictor: 'The Good the Bad and the Ugly (1966)'
# Finding best predictor: 'Speed 2: Cruise Control (1997)'
# Finding best predictor: 'The Lord of the Rings: The Fellowship of the Ring (2001)'
# Finding best predictor: 'The Talented Mr. Ripley (1999)'
# Finding best predictor: 'Casino (1995)'
# Finding best predictor: 'A Time to Kill (1996)'
# Finding best predictor: 'Blazing Saddles (1974)'
# Finding best predictor: 'The Doom Generation (1995)'
# Finding best predictor: 'Armageddon (1998)'
# Finding best predictor: 'X-Men (2000)'
# Finding best predictor: 'Arachnophobia (1990)'
# Finding best predictor: 'Stir Crazy (1980)'
# Finding best predictor: 'Billy Jack (1971)'
# Finding best predictor: 'The Silencers (1966)'
# Finding best predictor: 'The Three Musketeers (1993)'
# Finding best predictor: 'Girl Interrupted (1999)'
# Finding best predictor: 'Finding Nemo (2003)'
# Finding best predictor: 'Tropic of Cancer (1970)'
# Finding best predictor: 'The Sixth Sense (1999)'
# Finding best predictor: 'I Know What You Did Last Summer (1997)'
# Finding best predictor: 'Indiana Jones and the Kingdom of the Crystal Skull (2008)'
# Finding best predictor: 'Divine Secrets of the Ya-Ya Sisterhood (2002)'
# Finding best predictor: 'Ace Ventura: When Nature Calls (1995)'
# Finding best predictor: 'Dances with Wolves (1990)'
# Finding best predictor: 'Date and Switch (2014)'
# Finding best predictor: 'The Intouchables (2011)'
# Finding best predictor: 'Mrs. Doubtfire (1993)'
# Finding best predictor: 'Ghostbusters (2016)'
# Finding best predictor: 'Almost Famous (2000)'
# Finding best predictor: 'Blade Runner (1982)'
# Finding best predictor: 'Unforgiven (1992)'
# Finding best predictor: 'Rosemary's Baby (1968)'
# Finding best predictor: 'Cheaper by the Dozen (2003)'
# Finding best predictor: 'Can't Hardly Wait (1998)'
# Finding best predictor: 'Die Another Day (2002)'
# Finding best predictor: 'Toy Story 2 (1999)'
# Finding best predictor: 'Transformers: Age of Extinction (2014)'
# Finding best predictor: 'Like Stars on Earth (2007)'
# Finding best predictor: 'Terminator 2: Judgement Day (1991)'
# Finding best predictor: '25th Hour (2002)'
# Finding best predictor: 'Who's Afraid of Virginia Woolf (1966)'
# Finding best predictor: 'Adaption (2002)'
# Finding best predictor: 'Life is Beautiful (1997)'
# Finding best predictor: 'Room (2015)'
# Finding best predictor: 'Scream (1996)'
# Finding best predictor: 'The Evil Dead (1981)'
# Finding best predictor: 'Gangs of New York (2002)'
# Finding best predictor: 'Stand By Me (1986)'
# Finding best predictor: 'The Vow (2012)'
# Finding best predictor: 'Toy Story 3 (2010)'
# Finding best predictor: 'The Matrix Reloaded (2003)'
# Finding best predictor: 'Once Upon a Time in the West (1968)'
# Finding best predictor: 'Star Wars: Episode V - The Empire Strikes Back (1980)'
# Finding best predictor: 'War Games (1983)'
# Finding best predictor: 'Kill Bill: Vol. 2 (2004)'
# Finding best predictor: 'Saving Private Ryan (1998)'
# Finding best predictor: 'Just Married (2003)'
# Finding best predictor: 'Being John Malkovich (1999)'
# Finding best predictor: 'Father's Day (1997)'
# Finding best predictor: 'Batman (1989)'
# Finding best predictor: 'Se7en (1995)'
# Finding best predictor: 'Happy Gilmore (1996)'
# Finding best predictor: 'My Big Fat Greek Wedding (2002)'
# Finding best predictor: 'Boomerang (1992)'
# Finding best predictor: 'The Avengers (2012)'
# Finding best predictor: 'In America (2002)'
# Finding best predictor: 'Tarzan (1999)'
# Finding best predictor: 'Scent of a Woman (1992)'
# Finding best predictor: 'The Cabin in the Woods (2012)'
# Finding best predictor: 'Spider-Man (2002)'
# Finding best predictor: 'Broken Arrow (1996)'
# Finding best predictor: 'Baby Geniuses (1999)'
# Finding best predictor: 'Battlefield Earth (2000)'
# Finding best predictor: 'The Firm (1993)'
# Finding best predictor: 'De-Lovely (2004)'
# Finding best predictor: 'Die Hard (1988)'
# Finding best predictor: 'The Lord of the Rings: The Two Towers (2002)'
# Finding best predictor: 'The Blair Witch Project (1999)'
# Finding best predictor: 'Judge Dredd (1995)'
# Finding best predictor: '10 Things I Hate About You (1999)'
# Finding best predictor: 'The Insider (1999)'
# Finding best predictor: 'Erik the Viking (1989)'
# Finding best predictor: 'Pirates of the Caribbean: At World's End (2007)'
# Finding best predictor: 'The Ring (2002)'
# Finding best predictor: 'The Truman Show (1998)'
# Finding best predictor: 'Forrest Gump (1994)'
# Finding best predictor: 'I.Q. (1994)'
# Finding best predictor: 'Goodfellas (1990)'
# Finding best predictor: 'Uptown Girls (2003)'
# Finding best predictor: 'Beauty and the Beauty (1991)'
# Finding best predictor: 'Black Hawk Down (2001)'
# Finding best predictor: 'Knight and Day (2010)'
# Finding best predictor: 'The Shawshank Redemption (1994)'
# Finding best predictor: 'Sleepy Hollow (1999)'
# Finding best predictor: 'The Holiday (2006)'
# Finding best predictor: 'Sixteen Candles (1984)'
# Finding best predictor: '10000 BC (2008)'
# Finding best predictor: 'Austin Powers: The Spy Who Shagged Me (1999)'
# Finding best predictor: 'The Lion King (1994)'
# Finding best predictor: 'Child's Play (1988)'
# Finding best predictor: 'Anger Management (2002)'
# Finding best predictor: 'Angels in the Outfield (1994)'
# Finding best predictor: 'Wild Wild West (1999)'
# Finding best predictor: 'Split (2016)'
# Finding best predictor: 'Bad Boys (1995)'
# Finding best predictor: 'The Prestige (2006)'
# Finding best predictor: 'American Graffiti (1973)'
# Finding best predictor: 'Air Force One (1997)'
# Finding best predictor: 'Harry Potter and the Sorcerer's Stone (2001)'
# Finding best predictor: 'Close Encounters of the Third Kind (1977)'
# Finding best predictor: 'Hollow Man (2000)'
# Finding best predictor: 'Point Break (1991)'
# Finding best predictor: 'I Robot (2004)'
# Finding best predictor: 'Batman: The Dark Knight (2008)'
# Finding best predictor: 'Ghost (1990)'
# Finding best predictor: 'A Bug's Life (1998)'
# Finding best predictor: 'American Pie (1999)'
# Finding best predictor: 'Daredevil (2003)'
# Finding best predictor: 'The Bandit (1996)'
# Finding best predictor: 'Grease (1978)'
# Finding best predictor: 'The Girl Next Door (2004)'
# Finding best predictor: 'The Godfather (1972)'
# Finding best predictor: 'Cloverfield (2008)'
# Finding best predictor: 'Rush Hour 2 (2001)'
# Finding best predictor: 'Bruce Almighty (2003)'
# Finding best predictor: 'Girl With a Pearl Earring (2003)'
# Finding best predictor: 'Grown Ups 2 (2013)'
# Finding best predictor: 'Best Laid Plans (1999)'
# Finding best predictor: 'Bram Stoker's Dracula (1992)'
# Finding best predictor: 'Fahrenheit 9/11 (2004)'
# Finding best predictor: 'Donnie Darko (2001)'
# Finding best predictor: 'Bad Teacher (2011)'
# Finding best predictor: 'Cable Guy (1996)'
# Finding best predictor: 'Ice Age (2002)'
# Finding best predictor: 'Misery (1990)'
# Finding best predictor: '8 Mile (2002)'
# Finding best predictor: 'Harry Potter and the Deathly Hallows: Part 2 (2011)'
# Finding best predictor: 'Ouija: Origin of Evil (2016)'
# Finding best predictor: 'The Deer Hunter (1978)'
# Finding best predictor: 'There's Something About Mary (1998)'
# Finding best predictor: 'Zoolander (2001)'
# Finding best predictor: 'The Core (2003)'
# Finding best predictor: 'Spirited Away (2001)'
# Finding best predictor: 'Rocky (1976)'
# Finding best predictor: 'Traffic (2000)'
# Finding best predictor: 'Monsters  Inc.(2001)'
# Finding best predictor: 'Thoroughly Modern Millie (1967)'
# Finding best predictor: 'Requiem for a Dream (2000)'
# Finding best predictor: 'Downfall (2004)'
# Finding best predictor: 'L.A. Confidential (1997)'
# Finding best predictor: 'Chicago (2002)'
# Finding best predictor: 'Star Wars: Episode 1 - The Phantom Menace (1999)'
# Finding best predictor: 'Rain Man (1988)'
# Finding best predictor: 'What Lies Beneath (2000)'
# Finding best predictor: 'Toy Story (1995)'
# Finding best predictor: 'Boy's Don't Cry (1999)'
# Finding best predictor: 'Pearl Harbor (2001)'
# Finding best predictor: 'A.I. Artificial Intelligence (2001)'
# Finding best predictor: 'The Sting (1973)'
# Finding best predictor: 'Scream 3 (2000)'
# Finding best predictor: 'Congo (1995)'
# Finding best predictor: 'Bowling For Columbine (2002)'
# Finding best predictor: 'What Women Want (2000)'
# Finding best predictor: 'Home Alone (1990)'
# Finding best predictor: 'How the Grinch Stole Christmas (2000)'
# Finding best predictor: 'The Straight Story (1999)'
# Finding best predictor: 'The Hulk (2003)'
# Finding best predictor: 'Gigli (2002)'
# Finding best predictor: 'Rocky V (1991)'
# Finding best predictor: 'The Visit (2015)'
# Finding best predictor: 'Titanic (1997)'
# Finding best predictor: 'A Clockwork Orange (1971)'
# Finding best predictor: 'Charlie's Angels (2000)'
# Finding best predictor: 'Friday the 13th Part III (1982)'
# Finding best predictor: 'Hannibal (2001)'
# Finding best predictor: 'Pulp Fiction (1994)'
# Finding best predictor: 'Crimson Tide (1995)'
# Finding best predictor: 'Blow (2001)'
# Finding best predictor: 'Ran (1985)'
# Finding best predictor: 'Mulholland Dr. (2001)'
# Finding best predictor: 'Apocalypse Now (1979)'
# Finding best predictor: 'Cinema Paradiso (1988)'
# Finding best predictor: 'Double Jeopardy (1999)'
# Finding best predictor: 'The Big Lebowski (1998)'
# Finding best predictor: 'The Matrix (1999)'
# Finding best predictor: 'The Lord of the Rings: The Return of the King (2003)'
# Finding best predictor: 'Reservoir Dogs (1992)'
# Finding best predictor: 'Heavy Traffic (1973)'
# Finding best predictor: 'Memento (2000)'
# Finding best predictor: 'Dogville (2003)'
# Finding best predictor: 'American Psycho (2000)'
# Finding best predictor: 'Kill Bill: Vol. 1 (2003)'
# Finding best predictor: 'The Fugitive (1993)'
# Finding best predictor: 'Bend it Like Beckham (2002)'
# Finding best predictor: 'Austin Powers in Goldmember (2002)'
# Finding best predictor: 'The Mummy Returns (2001)'
# Finding best predictor: 'The Nightmare Before Christmas (1993)'
# Finding best predictor: 'La La Land (2016)'
# Finding best predictor: 'Flowers in the Attic (1987)'
# Finding best predictor: '28 Days Later (2002)'
# Finding best predictor: 'The Princess Bride (1987)'
# Finding best predictor: 'The Green Mile (1999)'
# Finding best predictor: 'Predator (1987)'
# Finding best predictor: 'A Night at the Roxbury (1998)'
# Finding best predictor: 'Ed Wood (1994)'
# Finding best predictor: 'Aliens (1986)'
# Finding best predictor: 'Meet the Parents (2000)'
# Finding best predictor: 'Independence Day (1996)'
# Finding best predictor: 'Who Framed Roger Rabbit (1988)'
# Finding best predictor: 'As Good as it Gets (1997)'
# Finding best predictor: 'Butch Cassidy and the Sundance Kid (1969)'
# Finding best predictor: 'You're Next (2011)'
# Finding best predictor: 'The Final Conflict (1981)'
# Finding best predictor: 'City of God (2002)'
# Finding best predictor: 'Star Wars: Episode VII - The Force Awakens (2015)'
# Finding best predictor: 'The Transporter (2002)'
# Finding best predictor: 'Cast Away (2000)'
# Finding best predictor: 'Bad Boys 2 (2003)'
# Finding best predictor: 'The Babadook (2014)'
# Finding best predictor: 'Saw (2004)'
# Finding best predictor: 'Star Wars: Episode VI - The Return of the Jedi (1983)'
# Finding best predictor: 'Scary Movie (2000)'
# Finding best predictor: 'E.T. The Extra-Terrestrial (1982)'
# Finding best predictor: 'American History X (1998)'
# Finding best predictor: 'FeardotCom (2002)'
# Finding best predictor: 'Halloween (1978)'
# Finding best predictor: 'Along Came a Spider (2002)'
# Finding best predictor: 'The Mist (2007)'
# Finding best predictor: 'Aladdin (1992)'
# Finding best predictor: 'Pirates of the Caribbean: The Curse of the Black Pearl (2003)'
# Finding best predictor: 'Men in Black (1997)'
# Finding best predictor: 'Eternal Sunshine of the Spotless Mind (2004)'
# Finding best predictor: 'Ocean's Eleven (2001)'
# Finding best predictor: 'Men in Black II (2002)'
# Finding best predictor: 'Cocktail (1988)'
# Finding best predictor: 'The Wolf of Wall Street (2013)'
# Finding best predictor: 'The Game (1997)'
# Finding best predictor: 'Red Sonja (1985)'
# Finding best predictor: 'One Flew Over the Cuckoo's Nest (1975)'
# Finding best predictor: 'Freddy Got Fingered (2001)'
# Finding best predictor: 'The Village (2004)'
# Finding best predictor: 'Miller's Crossing (1990)'
# Finding best predictor: 'My Best Friend's Wedding (1997)'
# Finding best predictor: 'Iron Man 3 (2013)'
# Finding best predictor: 'Big Daddy (1999)'
# Finding best predictor: 'Suspiria (1977)'
# Finding best predictor: 'The Passenger (1975)'
# Finding best predictor: 'The Station Agent (2003)'
# Finding best predictor: 'Jurassic Park (1993)'
# Finding best predictor: 'Captain America: Civil War (2016)'
# Finding best predictor: 'A Perfect Murder (1998)'
# Finding best predictor: 'Analyze That (2002)'
# Finding best predictor: 'Braveheart (1995)'
# Finding best predictor: 'Inception (2010)'
# Finding best predictor: 'Groundhog Day (1993)'
# Finding best predictor: 'The Lookout (2007)'
# Finding best predictor: '21 Grams (2003)'
# Finding best predictor: 'Gladiator (2000)'
# Finding best predictor: 'Midnight Cowboy (1969)'
# Finding best predictor: 'Fatal Attraction (1987)'
# Finding best predictor: 'House of Sand and Fog (2003)'
# Finding best predictor: 'On Golden Pond (1981)'
# Finding best predictor: 'The Mummy (1999)'
# Finding best predictor: 'The Descent (2005)'
# Finding best predictor: 'Runaway Bride (1999)'
# Finding best predictor: 'Harry Potter and the Goblet of Fire (2005)'
# Finding best predictor: 'Gods and Generals (2003)'
# Finding best predictor: 'My Father and My Son (2005)'
# Finding best predictor: 'X-Men 2 (2003)'
# Finding best predictor: 'The Usual Suspects (1995)'
# Finding best predictor: 'The Mask (1994)'
# Finding best predictor: 'Jaws (1975)'
# Finding best predictor: 'Harry Potter and the Chamber of Secrets (2002)'
# Finding best predictor: 'Patton (1970)'
# Finding best predictor: 'Anaconda (1997)'
# Finding best predictor: 'Twister (1996)'
# Finding best predictor: 'MacArthur (1977)'
# Finding best predictor: 'Look Who's Talking (1989)'

# %%
# ^ 
# R^2 - The proportion of the variance in the predicted variable (y) that can be explained by the features (X)
# R^2 = COD coefficient of determination 
# R^2 in (0,1), larger is better

# RMSE 
# A representation of the average distance between the observed data values and the predicted data values
# 0+, lower is better

# %%
print(len(best_data_all))
# Out:
# 400

# %%
# best, worst, avg_cod = rank_scores(this_movie_scores)

# print(best)
# print(worst)
# print(avg_cod)

# %%
# best_CODs

# %%
print(Average(best_CODs))
# Out:
# 0.42378171067196

# %%
# bins=len(average_CODs)
# sns.histplot(average_CODs, bins=bins, label="HIST")
# plt.title('Histogram of average COD values from movie models')

# bins=len(best_CODs)-20
bins=100
# sns.histplot(best_CODs, bins=bins, label="HIST", stat='density')
sns.histplot(best_CODs, bins=bins, label="HIST")
plt.title('Histogram of best COD values from movie models')

plt.xlabel('best COD')
# plt.ylabel('count of rating')
# # plt.legend()
# # plt.ylim([0, 1])
plt.show()

# %%
# now, find the top ten CODs and which movies they are predicted for, and their COD

# %%
easiest = sorted(best_CODs, reverse=True)[:10]
easiest
# Out:
# [0.6803586481291373,
#  0.6803586481291373,
#  0.6589551291567151,
#  0.658955129156715,
#  0.656520890202376,
#  0.656520890202376,
#  0.652789366279882,
#  0.652789366279882,
#  0.6478194879446582,
#  0.6478194879446582]

# %%
hardest = sorted(best_CODs)[:10]
hardest
# Out:
# [0.06788740393778636,
#  0.08161205184687803,
#  0.09486062776297266,
#  0.11020663183772728,
#  0.11090474997229205,
#  0.11547617566324198,
#  0.12326924270646422,
#  0.1298307779130955,
#  0.1327926626628233,
#  0.13489887779460064]

# %%
# get the best predictors
print("best predictors:")
for i in range(len(best_data_all)):
    
    item = best_data_all[i]
    if item['cod'] in easiest:
        print(item)
# Out:
# best predictors:
# {'movie': 'Erik the Viking (1989)', 'other_movie': 'I.Q. (1994)', 'cod': 0.6803586481291373}
# {'movie': 'I.Q. (1994)', 'other_movie': 'Erik the Viking (1989)', 'cod': 0.6803586481291373}
# {'movie': 'The Bandit (1996)', 'other_movie': 'Best Laid Plans (1999)', 'cod': 0.652789366279882}
# {'movie': 'Best Laid Plans (1999)', 'other_movie': 'The Bandit (1996)', 'cod': 0.652789366279882}
# {'movie': 'Congo (1995)', 'other_movie': 'The Straight Story (1999)', 'cod': 0.656520890202376}
# {'movie': 'The Straight Story (1999)', 'other_movie': 'Congo (1995)', 'cod': 0.656520890202376}
# {'movie': 'Ran (1985)', 'other_movie': 'Heavy Traffic (1973)', 'cod': 0.6478194879446582}
# {'movie': 'Heavy Traffic (1973)', 'other_movie': 'Ran (1985)', 'cod': 0.6478194879446582}
# {'movie': 'The Lookout (2007)', 'other_movie': 'Patton (1970)', 'cod': 0.658955129156715}
# {'movie': 'Patton (1970)', 'other_movie': 'The Lookout (2007)', 'cod': 0.6589551291567151}

# %%
# get the worst predictors
print("worst predictors:")
for i in range(len(best_data_all)):
    
    item = best_data_all[i]
    if item['cod'] in hardest:
        print(item)
# Out:
# worst predictors:
# {'movie': 'Black Swan (2010)', 'other_movie': 'Once Upon a Time in America (1984)', 'cod': 0.09486062776297266}
# {'movie': 'Planet of the Apes (2001)', 'other_movie': 'Equilibrium (2002)', 'cod': 0.13489887779460064}
# {'movie': 'Back to the Future (1985)', 'other_movie': '3000 Miles to Graceland (2001)', 'cod': 0.1298307779130955}
# {'movie': 'Clueless (1995)', 'other_movie': 'Love Story (1970)', 'cod': 0.11090474997229205}
# {'movie': 'Avatar (2009)', 'other_movie': "Pirates of the Caribbean: Dead Man's Chest (2006)", 'cod': 0.06788740393778636}
# {'movie': 'Interstellar (2014)', 'other_movie': 'Torque (2004)', 'cod': 0.08161205184687803}
# {'movie': 'The Cabin in the Woods (2012)', 'other_movie': 'The Evil Dead (1981)', 'cod': 0.11547617566324198}
# {'movie': 'Grown Ups 2 (2013)', 'other_movie': 'Knight and Day (2010)', 'cod': 0.12326924270646422}
# {'movie': 'La La Land (2016)', 'other_movie': 'The Lookout (2007)', 'cod': 0.11020663183772728}
# {'movie': 'The Wolf of Wall Street (2013)', 'other_movie': 'Memento (2000)', 'cod': 0.1327926626628233}
